# %%
from gensim.corpora.wikicorpus import WikiCorpus
import requests

# %%
def wiki2texts(wiki_data_path, wiki_texts_path='./wiki_texts.txt'):

    wiki_corpus = WikiCorpus(wiki_data_path, dictionary={})

    with open(wiki_text_path, 'w', encoding='utf-8') as output:
        for text in wiki_corpus.get_texts():
            output.write(b' '.join(text).decode('utf-8') + '\n')

# %%
def getWiki():
    base = "https://en.wikipedia.org/wiki/List_of_medical_abbreviations"
    r = requests.get(base)
    print(r.text)

# %%
#wiki2texts("https://en.wikipedia.org/wiki/List_of_medical_abbreviations")
#ny = wikipedia.url("https://en.wikipedia.org/wiki/List_of_medical_abbreviations")
getWiki()
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of medical abbreviations - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# ...
